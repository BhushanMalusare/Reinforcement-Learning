# %%
import gym, random
import numpy as np
from collections import Counter

# %%
env = gym.make("FrozenLake-v1", is_slippery=False)
state, _ = env.reset()
n_states = env.observation_space.n
n_actions = env.action_space.n
print(n_states)
print(n_actions)
# Out:
# 16
# 4

# %%
def initialize_q_table(n_state, n_actions):
    q_table = Counter()
    for state in range(n_state):
        for action in range(n_actions):
            q_table[(state, action)] = 0
    return q_table

# %%
q_table = initialize_q_table(n_states, n_actions)

# %%
def select_action(state, q_table, n_actions, epsilon=0.5):
    rand_float = random.random()
    if rand_float < epsilon:
        action = random.randrange(start=0, stop=n_actions)
        # print("Picking random action")
    else:
        # print("Picking max value action")
        action = None
        max_q_val = float('-inf')
        for act in range(n_actions):
            if q_table[(state, act)] > max_q_val:
                max_q_val = q_table[(state, act)]
                action = act
    return action

# %%
select_action(state, q_table, n_actions)
# Out:
# 0

# %%
def update_table(env, q_table, state, action, n_actions, alpha=0.1, gamma=0.99):
    nxt_st, reward, terminated, truncated, _ = env.step(action=action)
    q_val = q_table[(state, action)]
    max_next_q = max([q_table[nxt_st, n] for n in range(n_actions)])
    q_table[(state, action)] = q_val + alpha * (reward + (gamma * max_next_q) - q_val)
    return nxt_st, reward, terminated or truncated

# %%
def training_loop(env, q_table, n_actions, episodes=1000, epsilon=1.0, decay_rate=0.01, max_steps=200):
    rewards_per_episode = []
    
    for ep in range(episodes):
        state, _ = env.reset()
        total_reward = 0
        step_count = 0
        
        while True:
            nxt_action = select_action(state, q_table, n_actions, epsilon=epsilon)
            nx_st, reward, is_done = update_table(env, q_table, state, nxt_action, n_actions)
            total_reward += reward
            step_count += 1
            
            # Break if episode is done (goal reached or hole fallen into)
            if is_done:
                break
            
            # Break if maximum steps reached (timeout)
            if step_count >= max_steps:
                break
                
            state = nx_st
        
        rewards_per_episode.append(total_reward)
        
        # Decay epsilon AFTER each episode
        epsilon = max(0.01, epsilon * 0.995)
        
        if ep % 100 == 0:
            avg_reward = np.mean(rewards_per_episode[-100:]) if len(rewards_per_episode) >= 100 else np.mean(rewards_per_episode)
            print(f"Episode {ep}: Total reward = {total_reward}, Steps = {step_count}, Average reward (last 100) = {avg_reward:.3f}, Epsilon = {epsilon:.3f}")
    
    return rewards_per_episode

# %%
q_table = initialize_q_table(n_states, n_actions)

# Train the agent
print("Starting training...")
rewards = training_loop(env, q_table, n_actions, episodes=30000)
# Out:
# Starting training...
# Episode 0: Total reward = 0.0, Steps = 3, Average reward (last 100) = 0.000, Epsilon = 0.995
# Episode 100: Total reward = 1.0, Steps = 12, Average reward (last 100) = 0.090, Epsilon = 0.603
# Episode 200: Total reward = 0.0, Steps = 7, Average reward (last 100) = 0.390, Epsilon = 0.365
# Episode 300: Total reward = 0.0, Steps = 4, Average reward (last 100) = 0.690, Epsilon = 0.221
# Episode 400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.850, Epsilon = 0.134
# Episode 500: Total reward = 0.0, Steps = 3, Average reward (last 100) = 0.900, Epsilon = 0.081
# Episode 600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.900, Epsilon = 0.049
# Episode 700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.030
# Episode 800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.018
# Episode 900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.011
# Episode 1000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 1100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 1200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 1300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 1400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 1500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# b:\Pytorch\venv\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode 1600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 1700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 1800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 1900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 2000: Total reward = 1.0, Steps = 8, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 2100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 2200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 2300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 2400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 2500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 2600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 2700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 2800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 2900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 3000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 3100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 3200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 3300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 3400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 3500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 3600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 3700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 3800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 3900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 4000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 4100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 4200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 4300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 4400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 4500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 4600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 4700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.960, Epsilon = 0.010
# Episode 4800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 4900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 5000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 5100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 5200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 5300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 5400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 5500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 5600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 5700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 5800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 5900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 6000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 6100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 6200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 6300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 6400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 6500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 6600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 6700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 6800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 6900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 7000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 7100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 7200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 7300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 7400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 7500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 7600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 7700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 7800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 7900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 8000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 8100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 8200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 8300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 8400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 8500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 8600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 8700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 8800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 8900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 9000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 9100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 9200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 9300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 9400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 9500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 9600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 9700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 9800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 9900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 10000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 10100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 10200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 10300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 10400: Total reward = 0.0, Steps = 4, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 10500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 10600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 10700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 10800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 10900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 11000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 11100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 11200: Total reward = 1.0, Steps = 8, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 11300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 11400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 11500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 11600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 11700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.960, Epsilon = 0.010
# Episode 11800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 11900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 12000: Total reward = 0.0, Steps = 5, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 12100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 12200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 12300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 12400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 12500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 12600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 12700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 12800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 12900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 13000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 13100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.960, Epsilon = 0.010
# Episode 13200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 13300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 13400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 13500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 13600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 13700: Total reward = 1.0, Steps = 8, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 13800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 13900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 14000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 14100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 14200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 14300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 14400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 14500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 14600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 14700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 14800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 14900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 15000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 15100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 15200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 15300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 15400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 15500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 15600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 15700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 15800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 15900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 16000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 16100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 16200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 16300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 16400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 16500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 16600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 16700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 16800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 16900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 17000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 17100: Total reward = 0.0, Steps = 2, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 17200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 17300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 17400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 17500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 17600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 17700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 17800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 17900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 18000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 18100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 18200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 18300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 18400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 18500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 18600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 18700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 18800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 18900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 19000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 19100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 19200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 19300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 19400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 19500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 19600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 19700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 19800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 19900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 20000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 20100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 20200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 20300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 20400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 20500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 20600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 20700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 20800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 20900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 21000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 21100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 21200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 21300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 21400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 21500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 21600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 21700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 21800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 21900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 22000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 22100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 22200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 22300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 22400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 22500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 22600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 22700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 22800: Total reward = 1.0, Steps = 8, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 22900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 23000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 23100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 23200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 23300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 23400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 23500: Total reward = 0.0, Steps = 2, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 23600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 23700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 23800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 23900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 24000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 24100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 24200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 24300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 24400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 24500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 24600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 24700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 24800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 24900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 25000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 25100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 25200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 25300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 25400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 25500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 25600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 25700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 25800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 25900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 26000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 26100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 26200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 26300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 26400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 26500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 26600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 26700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 26800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 26900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 27000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 27100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 27200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 27300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 27400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 27500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 27600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 27700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 27800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 27900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 28000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 28100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 28200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 28300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 28400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 28500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 28600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 28700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 28800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 28900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 29000: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 29100: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 29200: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 29300: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.970, Epsilon = 0.010
# Episode 29400: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.980, Epsilon = 0.010
# Episode 29500: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 29600: Total reward = 1.0, Steps = 6, Average reward (last 100) = 0.990, Epsilon = 0.010
# Episode 29700: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 29800: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
# Episode 29900: Total reward = 1.0, Steps = 6, Average reward (last 100) = 1.000, Epsilon = 0.010
